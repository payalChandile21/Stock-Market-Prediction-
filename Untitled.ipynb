# %%
"""Install these two libraries if not instlled already"""
# !pip install pmdarima
# !pip install yfinance
# Out:
# Requirement already satisfied: pmdarima in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pmdarima) (1.5.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pmdarima) (1.11.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pmdarima) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pmdarima) (68.0.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pmdarima) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Requirement already satisfied: yfinance in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (0.2.12)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.26 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (41.0.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (2023.11.17)
# Requirement already satisfied: pycparser in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
# from statsmodels.tsa.arima_model import ARIMA
from datetime import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
import yfinance as yf
from pmdarima.arima import auto_arima
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.graphics.tsaplots import acf,pacf
import warnings
warnings.filterwarnings('ignore')
# !pip install yfinance
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import datetime
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: yfinance in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (0.2.12)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.26 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (41.0.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (2023.11.17)
# Requirement already satisfied: pycparser in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
import yfinance as yf
stock = yf.Ticker("TCS.NS")
print(stock.history(period="1d"))
# Out:
#                              Open    High     Low        Close   Volume  \
# Date
# 2025-02-14 00:00:00+05:30  3925.0  3948.0  3900.0  3934.850098  1681975
#
#                            Dividends  Stock Splits
# Date
# 2025-02-14 00:00:00+05:30        0.0           0.0

# %%
import yfinance as yf
stock = yf.Ticker("TCS.NS")
print(stock.history(period="1d"))
# Out:
#                              Open    High     Low        Close   Volume  \
# Date
# 2025-02-14 00:00:00+05:30  3925.0  3948.0  3900.0  3934.850098  1681975
#
#                            Dividends  Stock Splits
# Date
# 2025-02-14 00:00:00+05:30        0.0           0.0

# %%
 df = yf.download("ADANIENT.NS", start="2020-01-01", end="2023-02-12")
 df=df.round(2)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ADANIENT.NS: No data found for this date range, symbol may be delisted

# %%
# !pip install pandas numpy matplotlib seaborn yfinance scikit-learn tensorflow streamlit mpld3 ta
# Out:
# Requirement already satisfied: pandas in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (3.7.2)
# Requirement already satisfied: seaborn in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (0.12.2)
# Requirement already satisfied: yfinance in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (0.2.12)
# Requirement already satisfied: scikit-learn in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (1.5.0)
# Requirement already satisfied: tensorflow in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (2.15.0)
# Requirement already satisfied: streamlit in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (1.41.1)
# Collecting mpld3
#   Obtaining dependency information for mpld3 from https://files.pythonhosted.org/packages/95/6a/e3691bcc47485f38b09853207c928130571821d187cf174eed5418d45e82/mpld3-0.5.10-py3-none-any.whl.metadata
#   Downloading mpld3-0.5.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: requests>=2.26 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (41.0.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (13.7.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (3.1.41)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: jinja2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from mpld3) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: colorama in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: webencodings in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from jinja2->mpld3) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests>=2.26->yfinance) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: pycparser in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.25.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\10xtc_lap-5\anaconda5\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Downloading mpld3-0.5.10-py3-none-any.whl (202 kB)
#    ---------------------------------------- 0.0/202.6 kB ? eta -:--:--
#    -------------------------------- ------- 163.8/202.6 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 202.6/202.6 kB 4.1 MB/s eta 0:00:00
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py): started
#   Building wheel for ta (setup.py): finished with status 'done'
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29422 sha256=9c4415b60ce2112c2d59733e1a9e182435952f33f1f844d5513c1f848f1619ca
#   Stored in directory: c:\users\10xtc_lap-5\appdata\local\pip\cache\wheels\a1\d7\29\7781cc5eb9a3659d032d7d15bdd0f49d07d2b24fec29f44bc4
# Successfully built ta
# Installing collected packages: ta, mpld3
# Successfully installed mpld3-0.5.10 ta-0.11.0

# %%
# %%writefile app.py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM, GRU
from sklearn.preprocessing import MinMaxScaler
import datetime
# import pickle
import streamlit as st
import model_building as m
import technical_analysis as t
import correlation_analysis as c
import mpld3
import streamlit.components.v1 as components
from ta.trend import MACD
from ta.momentum import RSIIndicator
from ta.volatility import BollingerBands
import tensorflow as tf
import warnings
import os

# Ignore TensorFlow deprecation warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  
warnings.filterwarnings("ignore", category=UserWarning, module="tensorflow")



with st.sidebar:
    st.markdown("# Stock Analysis & Forecasting")
    user_input = st.selectbox(
    'Please select the stock for forecasting and technical analysis ',
    ('ADANIENT.NS','TATASTEEL.NS','PAGEIND.NS','EICHERMOT.NS','INFY.NS'))
    # user_input = st.text_input('Enter Stock Name', "ADANIENT.NS")
    st.markdown("### Choose Date for your anaylsis")
    date_from = st.date_input("From",datetime.date(2020, 1, 1))
    date_to = st.date_input("To",datetime.date(2023, 2, 25))
    options = st.multiselect(
        'Select stocks for diversification analysis',
        ['ADANIENT.NS','TATASTEEL.NS','PAGEIND.NS','EICHERMOT.NS','INFY.NS'],
        ['ADANIENT.NS']
    )
    # st.write('You selected:', options[0])
    btn = st.button('Submit') 

#adding a button
if btn:
    df = yf.download(user_input, start=date_from, end=date_to)
    plotdf, future_predicted_values =m.create_model(df)


    st.markdown("### Original vs predicted close price")
    fig= plt.figure(figsize=(20,10))
    sns.lineplot(data=plotdf)
    st.pyplot(fig)

    st.markdown("### Next 10 days forecast")
    list_of_days = ["Day 1", "Day 2", "Day 3", "Day 4", "Day 5", "Day 6", "Day 7","Day 8", "Day 9", "Day 10"]

    for i,j in zip(st.tabs(list_of_days),range(10)):
        with i:
            st.write(future_predicted_values.iloc[j:j+1])


    st.markdown("### Adj Close Price")
    fig= plt.figure(figsize=(20,10))
    t.last_2_years_price_plot(df)
    st.pyplot(fig)

    st.markdown("### Daily Percentage Changes")
    fig= plt.figure(figsize=(20,10))
    t.daily_percent_change_plot(df)
    st.pyplot(fig)
    
    st.markdown("### Daily Percentage Changes Histogram")
    fig= plt.figure(figsize=(20,10))
    t.daily_percent_change_histogram(df)
    st.pyplot(fig)

    st.markdown("### Trend Analysis")
    fig= plt.figure(figsize=(20,10))
    t.trend_pie_chart(df)
    st.pyplot(fig)

    st.markdown("### Volume Plot")
    fig= plt.figure(figsize=(20,10))
    t.volume_plot(df)
    st.pyplot(fig)

    st.markdown("### Volatility Plot")
    fig= plt.figure(figsize=(20,10))
    t.volatility_plot(df)
    st.pyplot(fig)


    st.markdown("## Technical Analysis")

    st.markdown("### MACD Indicator")
    
    fig= plt.figure(figsize=(20,10))
    t.plot_price_and_signals(t.get_macd(df),'MACD')
    st.pyplot(fig)

    fig= plt.figure(figsize=(20,10))
    t.plot_macd(df)
    st.pyplot(fig)

    st.write(" ***:blue[Strategy:]:***")
    st.write(":red[Sell  Signal:] The cross over: When the MACD line is below the signal line.")
    st.write(":green[Buy Signal:] The cross over: When the MACD line is above the signal line.")

    st.markdown("### RSI Indicator")

    fig= plt.figure(figsize=(20,10))
    t.plot_price_and_signals(t.get_rsi(df),'RSI')
    st.pyplot(fig)

    fig= plt.figure(figsize=(20,10))
    t.plot_rsi(df)
    st.pyplot(fig)

    st.write(" ***:blue[Strategy:]:***")
    st.write(":red[Sell  Signal:] When RSI increases above 70%")
    st.write(":green[Buy Signal:] When RSI decreases below 30%.")


    st.markdown("### Bollinger Indicator")

    fig= plt.figure(figsize=(20,10))
    t.plot_price_and_signals(t.get_bollinger_bands(df),'Bollinger_Bands')
    st.pyplot(fig)

    fig= plt.figure(figsize=(20,10))
    t.plot_bollinger_bands(df)
    st.pyplot(fig)

    st.write(" ***:blue[Strategy:]:***")
    st.write(":red[Sell  Signal:] As soon as the market price touches the upper Bollinger band")
    st.write(":green[Buy Signal:] As soon as the market price touches the lower Bollinger band")

    st.markdown("### SMA Indicator")
   
    fig= plt.figure(figsize=(20,10))
    t.sma_plot(df)
    st.pyplot(fig)
    st.write(" ***:blue[Strategy:]:***")
    st.write(":red[Sell  Signal:] When the 50-day SMA crosses below the 200-day SMA.")
    st.write(":green[Buy Signal:] When the 50-day SMA crosses above the 200-day SMA.")

    st.markdown("### EMA Indicator")
   
    fig= plt.figure(figsize=(20,10))
    t.ema_plot(df)
    st.pyplot(fig)
    st.write(" ***:blue[Strategy:]:***")
    st.write(":red[Sell  Signal:] When the 50-day EMA crosses below the 200-day EMA.")
    st.write(":green[Buy Signal:] When the 50-day EMA crosses above the 200-day EMA.")
   
    st.markdown("### Diversified Portfolio Analysis")
    combined_df = yf.download(options, start=date_from, end=date_to)['Adj Close']
    combined_df = combined_df.round(2)
    
    fig= plt.figure(figsize=(20,10))
    c.corr_plot(combined_df)
    st.pyplot(fig)

    st.write(" ***:blue[Strategy:]:*** All the stocks which do not show significant correlation can be included in a portfolio.")
    
    
else:
    st.write('Please click on the submit to get the analysis') #displayed when the button is unclicked
# Out:
# Overwriting app.py
